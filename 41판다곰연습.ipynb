# %% [markdown]
# ### SERIES

# %%
import pandas as pd

# %%
s1=pd.Series([10,20,30])
s1[1]
# Out:
# np.int64(20)

# %%
col_idx=['A','B','C']
data=[10,20,30]
s2=pd.Series(data,col_idx)

# %%
s2['A':'C']
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %%
dict_data={'A':10,'B':20,'C':30}
type(dict_data)
s3=pd.Series(dict_data)

# %%
s3
# Out:
# A    10
# B    20
# C    30
# dtype: int64
