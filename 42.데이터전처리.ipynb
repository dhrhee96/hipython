# %% [markdown]
# # long data 만들기
#
# -각 변수는 하나의 컬럼에 배치
# - 각 관측치는 한행에 1건씩 분리되어 배치
# - 각 값은 개별 셀에 배치
#
# -melt()
# -piovt()
# -pivot_table(): 집계함수 적용

# %%
import pandas as pd

# %%
df=pd.read_csv(r'./data/pew.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  $75-100k  \
# 0  Agnostic     27       34       60       81       76      137       122
# 1   Atheist     12       27       37       52       35       70        73
#
#    $100-150k  >150k  Don't know/refused
# 0        109     84                  96
# 1         59     74                  76

# %%
pd.melt(df)
# Out:
#                variable               value
# 0              religion            Agnostic
# 1              religion             Atheist
# 2              religion            Buddhist
# 3              religion            Catholic
# 4              religion  Don’t know/refused
# ..                  ...                 ...
# 193  Don't know/refused                  73
# 194  Don't know/refused                  18
# 195  Don't know/refused                  71
# 196  Don't know/refused                   8
# 197  Don't know/refused                 597
#
# [198 rows x 2 columns]

# %%
df.melt(id_vars='religion').sort_values('religion').head(18)
# Out:
#      religion            variable  value
# 0    Agnostic               <$10k     27
# 144  Agnostic               >150k     84
# 162  Agnostic  Don't know/refused     96
# 126  Agnostic           $100-150k    109
# 36   Agnostic             $20-30k     60
# 108  Agnostic            $75-100k    122
# 18   Agnostic             $10-20k     34
# 90   Agnostic             $50-75k    137
# 72   Agnostic             $40-50k     76
# 54   Agnostic             $30-40k     81
# 109   Atheist            $75-100k     73
# 19    Atheist             $10-20k     27
# 55    Atheist             $30-40k     52
# 91    Atheist             $50-75k     70
# 127   Atheist           $100-150k     59
# 145   Atheist               >150k     74
# 73    Atheist             $40-50k     35
# 37    Atheist             $20-30k     37

# %%
df_melt=df.melt(id_vars='religion')
df_melt
# Out:
#                   religion            variable  value
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
cond=df_melt['religion']=='Agnostic'

# %%
df_melt.loc[cond]
# Out:
#      religion            variable  value
# 0    Agnostic               <$10k     27
# 18   Agnostic             $10-20k     34
# 36   Agnostic             $20-30k     60
# 54   Agnostic             $30-40k     81
# 72   Agnostic             $40-50k     76
# 90   Agnostic             $50-75k    137
# 108  Agnostic            $75-100k    122
# 126  Agnostic           $100-150k    109
# 144  Agnostic               >150k     84
# 162  Agnostic  Don't know/refused     96

# %%
df_melt_rename=df_melt.rename(columns={'variable':'income','value':'conunt'})

# %%
df_melt_rename
# Out:
#                   religion              income  conunt
# 0                 Agnostic               <$10k      27
# 1                  Atheist               <$10k      12
# 2                 Buddhist               <$10k      27
# 3                 Catholic               <$10k     418
# 4       Don’t know/refused               <$10k      15
# ..                     ...                 ...     ...
# 175               Orthodox  Don't know/refused      73
# 176        Other Christian  Don't know/refused      18
# 177           Other Faiths  Don't know/refused      71
# 178  Other World Religions  Don't know/refused       8
# 179           Unaffiliated  Don't know/refused     597
#
# [180 rows x 3 columns]

# %%
df1=pd.read_csv(r'./data/billboard.csv')
df1
# Out:
#      year            artist                    track  time date.entered  wk1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29   86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01   85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18   95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02   99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29   60
#
# ...

# %%
df1_melt=df1.melt(id_vars='artist')
cond1=df1_melt['artist']=='2 Pac'
df1_melt.loc[cond1]
df1_melt_rename=df1_melt.rename(columns={'variable':'Music time','value':'year'})
df1_melt_rename
# Out:
#                  artist Music time  year
# 0                 2 Pac       year  2000
# 1               2Ge+her       year  2000
# 2          3 Doors Down       year  2000
# 3          3 Doors Down       year  2000
# 4              504 Boyz       year  2000
# ...                 ...        ...   ...
# 25355       Yankee Grey       wk76   NaN
# 25356  Yearwood, Trisha       wk76   NaN
# 25357   Ying Yang Twins       wk76   NaN
# 25358     Zombie Nation       wk76   NaN
# 25359   matchbox twenty       wk76   NaN
#
# [25360 rows x 3 columns]

# %% [markdown]
# # aply

# %%
df=pd.DataFrame({
  "a":[10,20,30],
  "b":[20,30,40]
})
df**2
# Out:
#      a     b
# 0  100   400
# 1  400   900
# 2  900  1600

# %%
df/10 #vectorisation
# Out:
#      a    b
# 0  1.0  2.0
# 1  2.0  3.0
# 2  3.0  4.0

# %%
def make_sq(x,e=2):
    return x**e

# %%
df.apply(make_sq,e=2.71)
# Out:
#               a             b
# 0    512.861384   3355.763054
# 1   3355.763054  10069.284236
# 2  10069.284236  21957.484078

# %%
import pandas as pd

# 직원 명단 DataFrame 생성
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 45, 35, 32, 28],
    'Salary': [5000, 7000, 6500, 5500, 6000]
}
sal_df=pd.DataFrame(data)
sal_df
# Out:
#       Name  Age  Salary
# 0    Alice   25    5000
# 1      Bob   45    7000
# 2  Charlie   35    6500
# 3    David   32    5500
# 4      Eva   28    6000

# %%
def age_category(age):
  if age<30:
     return '20대'
  elif age<40 :
    return '30대'
  else:
    return '40대'

# %%
sal_df['Age_category']=sal_df['Age'].apply(age_category)
sal_df
# Out:
#       Name  Age  Salary Age_category   Bonus
# 0    Alice   25    5000          20대  1000.0
# 1      Bob   45    7000          40대  1400.0
# 2  Charlie   35    6500          30대  1300.0
# 3    David   32    5500          30대  1100.0
# 4      Eva   28    6000          20대  1200.0

# %%
# 보우너스
sal_df['Bonus'] = sal_df['Salary'] * 0.2

# %%
sal_df
# Out:
#       Name  Age  Salary Age_category   Bonus
# 0    Alice   25    5000          20대  1000.0
# 1      Bob   45    7000          영포티  1400.0
# 2  Charlie   35    6500          30대  1300.0
# 3    David   32    5500          30대  1100.0
# 4      Eva   28    6000          20대  1200.0

# %% [markdown]
# # 데이터 병합

# %%
df_1=pd.read_csv('./data/concat_1.csv')
df_2=pd.read_csv('./data/concat_2.csv')
df_3=pd.read_csv('./data/concat_3.csv')

# %%
df_1,df_2,df_3
# Out:
# (    A   B   C   D
#  0  a0  b0  c0  d0
#  1  a1  b1  c1  d1
#  2  a2  b2  c2  d2
#  3  a3  b3  c3  d3,
#      A   B   C   D
#  0  a4  b4  c4  d4
#  1  a5  b5  c5  d5
#  2  a6  b6  c6  d6
#  3  a7  b7  c7  d7,
#       A    B    C    D
#  0   a8   b8   c8   d8
#  1   a9   b9   c9   d9
#  2  a10  b10  c10  d10
#  3  a11  b11  c11  d11)

# %%
total_df=pd.concat([df_1,df_2,df_3],ignore_index=True)

# %%
total_df.loc[3]
# Out:
# A    a3
# B    b3
# C    c3
# D    d3
# Name: 3, dtype: object

# %%
#
# total_df.iloc[3]
total_df.reset_index()#
total_df
# Out:
#       A    B    C    D
# 0    a0   b0   c0   d0
# 1    a1   b1   c1   d1
# 2    a2   b2   c2   d2
# 3    a3   b3   c3   d3
# 4    a4   b4   c4   d4
# 5    a5   b5   c5   d5
# 6    a6   b6   c6   d6
# 7    a7   b7   c7   d7
# 8    a8   b8   c8   d8
# 9    a9   b9   c9   d9
# 10  a10  b10  c10  d10
# 11  a11  b11  c11  d11

# %%
add_ser = pd.Series(['a100', 'b100', 'c100', 'd100'], index=['A', 'B', 'C', 'D']).to_frame().T

# %%
total_df_add=pd.concat([total_df,add_ser],ignore_index=True)
total_df_add
# Out:
#        A     B     C     D
# 0     a0    b0    c0    d0
# 1     a1    b1    c1    d1
# 2     a2    b2    c2    d2
# 3     a3    b3    c3    d3
# 4     a4    b4    c4    d4
# 5     a5    b5    c5    d5
# 6     a6    b6    c6    d6
# 7     a7    b7    c7    d7
# 8     a8    b8    c8    d8
# 9     a9    b9    c9    d9
# 10   a10   b10   c10   d10
# 11   a11   b11   c11   d11
# 12  a100  b100  c100  d100

# %% [markdown]
# 시리즈를 행으로-> concat
#
# -dataframe(원본과 동일한 column을 같는 데이터프레임 생성)
# -column = 인덱스이름 시리즈 생성
# -빈데이터프레임에 행으로 시리즈를 추가
# -concat(원본,빈데이터 프레임)

# %% [markdown]
# # merge()
# - 키를 기준으로 합친다
# - sql 에서 join

# %%
import pandas as pd

# %%
# 매출데이터
sales_data = pd.DataFrame({ 'CustomerID': [101, 102, 103, 104], 'Date': ['2023-01-01', '2023-01-03', '2023-01-05', '2023-01-07'], 'Amount': [250, 300, 150, 400] })
# 고객데이터
customer_data = pd.DataFrame({ 'CustomerID': [101, 102, 103, 105], 'Name': ['Alice', 'Bob', 'Charlie', 'Eva'], 'Region': ['North', 'South', 'East', 'West'] })

# %%
sales_data.info()
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  4 non-null      int64
#  1   Date        4 non-null      object
#  2   Amount      4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  4 non-null      int64
#  1   Name        4 non-null      object
#  2   Region      4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
pd.merge(customer_data,sales_data,on='CustomerID')
# Out:
#    CustomerID     Name Region        Date  Amount
# 0         101    Alice  North  2023-01-01     250
# 1         102      Bob  South  2023-01-03     300
# 2         103  Charlie   East  2023-01-05     150

# %%
pd.merge(customer_data,sales_data,on='CustomerID',how='right')
# Out:
#    CustomerID     Name Region        Date  Amount
# 0         101    Alice  North  2023-01-01     250
# 1         102      Bob  South  2023-01-03     300
# 2         103  Charlie   East  2023-01-05     150
# 3         104      NaN    NaN  2023-01-07     400

# %% [markdown]
# how- 병합 기준 지정
# - left
# - right
# - inner(default)
# - outer
# - on(병합키 지정)

# %% [markdown]
# # 그룹연산
# groupby() + aggregation 집계

# %%
gap_df=pd.read_csv(r'./data/gapminder.tsv',sep='\t')
gap_df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gap_df.tail(5)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
gap_df.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
gap_df['country'].unique().shape
# Out:
# (142,)

# %%
gap_df['continent'].unique().shape
gap_df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
gap_df['year'].unique()
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %%
gap_df.groupby('country')[['lifeExp']].count().describe()
# Out:
#        lifeExp
# count    142.0
# mean      12.0
# std        0.0
# min       12.0
# 25%       12.0
# 50%       12.0
# 75%       12.0
# max       12.0

# %%
gap_df.groupby('country').get_group('Afghanistan')
# Out:
#         country continent  year  lifeExp       pop   gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415  635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405  726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923  974.580338

# %%
gap_df.groupby('continent')['country'].count()
# Out:
# continent
# Africa      624
# Americas    300
# Asia        396
# Europe      360
# Oceania      24
# Name: country, dtype: int64

# %%
gap_df.groupby('continent')['country'].count().std()
# Out:
# 215.4325880641088

# %%
gap_df.groupby('continent')['country'].count().describe()
# Out:
# count      5.000000
# mean     340.800000
# std      215.432588
# min       24.000000
# 25%      300.000000
# 50%      360.000000
# 75%      396.000000
# max      624.000000
# Name: country, dtype: float64

# %% [markdown]
# # 자동차 생산량 데이터 모양 만들기

# %%
veh_df=pd.read_csv('./data/vehicle_prod.csv',index_col=0)

# %%
veh_df.rename(columns={'Unnamed: 0':'Country'},inplace=True)
veh_df
# Out:
#          2007   2008   2009   2010   2011
# China    7.71   7.95  11.96  15.84  16.33
# EU      19.02  17.71  15.00  16.70  17.48
# US      10.47   8.45   5.58   7.60   8.40
# Japan   10.87  10.83   7.55   9.09   7.88
# Korea    4.04   3.78   3.45   4.20   4.62
# Mexico   2.01   2.05   1.50   2.25   2.54

# %%
(veh_df[['2007']])
# Out:
#          2007
# China    7.71
# EU      19.02
# US      10.47
# Japan   10.87
# Korea    4.04
# Mexico   2.01

# %%
veh_df.sum()
# Out:
# 2007    54.12
# 2008    50.77
# 2009    45.04
# 2010    55.68
# 2011    57.25
# dtype: float64

# %%
# 총생산량

# %%
veh_df['total_production']=veh_df.sum(axis=1)
veh_df
# Out:
#          2007   2008   2009   2010   2011  total_production
# China    7.71   7.95  11.96  15.84  16.33            119.58
# EU      19.02  17.71  15.00  16.70  17.48            171.82
# US      10.47   8.45   5.58   7.60   8.40             81.00
# Japan   10.87  10.83   7.55   9.09   7.88             92.44
# Korea    4.04   3.78   3.45   4.20   4.62             40.18
# Mexico   2.01   2.05   1.50   2.25   2.54             20.70

# %% [markdown]
# # 결측치처리

# %%
import numpy as np
pd.NA,np.nan
# Out:
# (<NA>, nan)

# %%
pd.isnull(np.nan),pd.isnull(pd.NA)
# Out:
# (True, True)

# %%
data = {
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'age': [25, np.nan, 30, 22, np.nan],
    'score': [90, 85, np.nan, 88, 95],
    'city': ['Seoul', 'Busan', np.nan, 'Incheon', 'Seoul']
}
data
# Out:
# {'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
#  'age': [25, nan, 30, 22, nan],
#  'score': [90, 85, nan, 88, 95],
#  'city': ['Seoul', 'Busan', nan, 'Incheon', 'Seoul']}

# %%
df = pd.DataFrame(data)

# 결측치 채우기 및 포맷 정리
#
#df['score'] = df['score'].fillna(0).round(1)
#df['city'] = df['city'].fillna(0)

#df['age'].mean()
df
# Out:
#       name   age  score     city
# 0    Alice  25.0   90.0    Seoul
# 1      Bob   NaN   85.0    Busan
# 2  Charlie  30.0    NaN      NaN
# 3    David  22.0   88.0  Incheon
# 4      Eva   NaN   95.0    Seoul

# %%
df['score'] = df['score'].fillna(df['score'].median()).round(1)
df['age'] = df['age'].fillna(df['age'].mean()).round(1)
df['city'] = df['city'].fillna(0)
df
# Out:
#       name   age  score     city
# 0    Alice  25.0   90.0    Seoul
# 1      Bob  25.7   85.0    Busan
# 2  Charlie  30.0   89.0        0
# 3    David  22.0   88.0  Incheon
# 4      Eva  25.7   95.0    Seoul

# %% [markdown]
# # 타이타닉 연습이다이!

# %%
titanic_df=pd.read_csv('./data/titanic.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df['Age'] =titanic_df['Age'].fillna(titanic_df['Age'].median(),inplace=True).round(1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14816\466776867.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df['Age'] =titanic_df['Age'].fillna(titanic_df['Age'].median(),inplace=True).round(1)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 titanic_df['Age'] =titanic_df['Age'].fillna(titanic_df['Age'].median(),inplace=True).round(1)
#
# ...

# %%
titanic_df['Age'].mean()
# Out:
# nan

# %%
titanic_df['Age'].plot(kind='hist')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 titanic_df['Age'].plot(kind='hist')
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\stats\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
titanic_df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
#'unknown'
titanic_df['Cabin'].fillna('unknown',inplace=True)

# %%
titanic_df['Cabin'].value_counts().head(5)
# Out:
# Cabin
# unknown        687
# G6               4
# C23 C25 C27      4
# B96 B98          4
# F2               3
# Name: count, dtype: int64

# %% [markdown]
# # Embarked 속성

# %%
titanic_df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
titanic_df['Sex'].map({'male':0, 'female':1})
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Sex, Length: 891, dtype: int64

# %%
! pip install kagglehub[pandas-datasets]
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [kagglesdk]
#    -------------------------- ------------- 2/3 [kagglehub]
#    ---------------------------------------- 3/3 [kagglehub]
#
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dolbokostya/math-problems-with-answers-aime-imo")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 125k/125k [00:00<00:00, 582kB/s]
# Extracting files...
# Path to dataset files: C:\Users\Admin\.cache\kagglehub\datasets\dolbokostya\math-problems-with-answers-aime-imo\versions\1

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "dolbokostya/math-problems-with-answers-aime-imo",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12960\2976249056.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 10
#       7 file_path = ""
#       9 # Load the latest version
# ---> 10 df = kagglehub.load_dataset(
#      11   KaggleDatasetAdapter.PANDAS,
#      12   "dolbokostya/math-problems-with-answers-aime-imo",
#      13   file_path,
#      14   # Provide any additional arguments like
#      15   # sql_query or pandas_kwargs. See the
#      16   # documenation for more information:
#      17   # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
#      18 )
#      20 print("First 5 records:", df.head())
#
# ...
