# %%
from dotenv import load_dotenv
import os

load_dotenv()

OPENAI_API_KEY = os.environ['OPENAI_API_KEY']
#PINECONE_API_KEY = os.environ['PINECONE_API_KEY']

print("API 키 로드 완료")
print(f"OpenAI Key: {OPENAI_API_KEY[:10]}...")
# Out:
# API 키 로드 완료
# OpenAI Key: 여기에_본인키_입력...

# %%
# Step 2 : LCEL 기본 체인 동작 확인
from dotenv import load_dotenv
load_dotenv()

from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model="gpt-4o-mini")
prompt = PromptTemplate.from_template("{topic}에 대해 한 문장으로 설명해줘")
chain = prompt | llm | StrOutputParser()

result = chain.invoke({"topic": "RAG"})
print(result)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[2], line 13
#       9 llm = ChatOpenAI(model="gpt-4o-mini")
#      10 prompt = PromptTemplate.from_template("{topic}에 대해 한 문장으로 설명해줘")
#      11 chain = prompt | llm | StrOutputParser()
#      12
# ---> 13 result = chain.invoke({"topic": "RAG"})
#      14 print(result)
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\langchain_core\runnables\base.py:3157, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3155                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3156             else:
# -> 3157                 input_ = context.run(step.invoke, input_, config)
#    3158 # finish the root run
#    3159 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\langchain_core\language_models\chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\langchain_core\language_models\chat_models.py:1185, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1176 @override
#    1177 def generate_prompt(
#    1178     self,
#    (...)   1182     **kwargs: Any,
#    1183 ) -> LLMResult:
#    1184     prompt_messages = [p.to_messages() for p in prompts]
# -> 1185     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\langchain_core\language_models\chat_models.py:995, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     992 for i, m in enumerate(input_messages):
#     993     try:
#     994         results.append(
# --> 995             self._generate_with_cache(
#     996                 m,
#     997                 stop=stop,
#     998                 run_manager=run_managers[i] if run_managers else None,
#     999                 **kwargs,
#    1000             )
#    1001         )
#    1002     except BaseException as e:
#    1003         if run_managers:
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\langchain_core\language_models\chat_models.py:1297, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1295     result = generate_from_stream(iter(chunks))
#    1296 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1297     result = self._generate(
#    1298         messages, stop=stop, run_manager=run_manager, **kwargs
#    1299     )
#    1300 else:
#    1301     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\langchain_openai\chat_models\base.py:1492, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1490     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1491         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1492     raise e
#    1493 if (
#    1494     self.include_response_headers
#    1495     and raw_response is not None
#    1496     and hasattr(raw_response, "headers")
#    1497 ):
#    1498     generation_info = {"headers": dict(raw_response.headers)}
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\langchain_openai\chat_models\base.py:1483, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1476         return _construct_lc_result_from_responses_api(
#    1477             response,
#    1478             schema=original_schema_obj,
#    1479             metadata=generation_info,
#    1480             output_version=self.output_version,
#    1481         )
#    1482     else:
# -> 1483         raw_response = self.client.with_raw_response.create(**payload)
#    1484         response = raw_response.parse()
#    1485 except openai.BadRequestError as e:
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\openai\resources\chat\completions\completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\openai\_base_client.py:991, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     988 options = self._prepare_options(options)
#     990 remaining_retries = max_retries - retries_taken
# --> 991 request = self._build_request(options, retries_taken=retries_taken)
#     992 self._prepare_request(request)
#     994 kwargs: HttpxSendArgs = {}
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\openai\_base_client.py:510, in BaseClient._build_request(self, options, retries_taken)
#     507     else:
#     508         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 510 headers = self._build_headers(options, retries_taken=retries_taken)
#     511 params = _merge_mappings(self.default_query, options.params)
#     512 content_type = headers.get("Content-Type")
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\openai\_base_client.py:443, in BaseClient._build_headers(self, options, retries_taken)
#     440 self._validate_headers(headers_dict, custom_headers)
#     442 # headers are case-insensitive while dictionaries are not.
# --> 443 headers = httpx.Headers(headers_dict)
#     445 idempotency_header = self._idempotency_header
#     446 if idempotency_header and options.idempotency_key and idempotency_header not in headers:
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\httpx\_models.py:156, in Headers.__init__(self, headers, encoding)
#     154     for k, v in headers.items():
#     155         bytes_key = _normalize_header_key(k, encoding)
# --> 156         bytes_value = _normalize_header_value(v, encoding)
#     157         self._list.append((bytes_key, bytes_key.lower(), bytes_value))
#     158 elif headers is not None:
#
# File c:\Users\Admin\miniconda3\envs\langchain_rag_env\Lib\site-packages\httpx\_models.py:82, in _normalize_header_value(value, encoding)
#      80 if not isinstance(value, str):
#      81     raise TypeError(f"Header value must be str or bytes, not {type(value)}")
# ---> 82 return value.encode(encoding or "ascii")
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 7-9: ordinal not in range(128)

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.15
