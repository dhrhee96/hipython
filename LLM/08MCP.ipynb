# %%
# !pip install fastmcp
# !pip install mcp
# !pip install notion-client
# !pip install langchain_mcp_adapters
# Out:
# ...
#   Using cached exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# ...
#    ---------------------------------------- 0.0/728.6 kB ? eta -:--:--
#    ---------------------------------------- 728.6/728.6 kB 29.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 33.5 MB/s  0:00:00
# ...
# Using cached exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# ...
#    ---------------------------------------- 0.0/633.2 kB ? eta -:--:--
#    ---------------------------------------- 633.2/633.2 kB 11.6 MB/s  0:00:00
# ...
#
#    -- -------------------------------------  2/29 [pywin32-ctypes]
#    ---- -----------------------------------  3/29 [pyjwt]
#    ----------- ----------------------------  8/29 [griffelib]
#    ----------- ----------------------------  8/29 [griffelib]
#    ----------- ----------------------------  8/29 [griffelib]
#    ------------- -------------------------- 10/29 [docutils]
# ...
