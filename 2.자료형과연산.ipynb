# %% [markdown]
# # 기본자료형 : 정수형,실수형,문자형,부울형
# # 복합자료형 : list,tuple,dict,set

# %% [markdown]
# # 기본자료형

# %% [markdown]
# ## int 정수형

# %%
20,type(20)
# Out:
# (20, int)

# %%
a =20 
a
# Out:
# 20

# %%
a=0b101 #Ob는 이진수
a
# Out:
# 5

# %%
a=0o10
a
# Out:
# 8

# %%
a=0b1000
a
# Out:
# 8

# %%
a=0x16d 
a
# Out:
# 365

# %% [markdown]
# ## float

# %%
b=3.14
type(b),b
# Out:
# (float, 3.14)

# %% [markdown]
# ## 지수의 표기

# %%
a=10e2
a
# Out:
# 1000.0

# %%
a=10e-2
a
# Out:
# 0.1

# %%
3.141592e9
# Out:
# 3141592000.0

# %% [markdown]
# ## boolean 부울형
# True == 1 and False == 0 예약어

# %%
a=10
a=3.14
a=3.14e5 
a= True 
b= False 
a,b
# Out:
# (True, False)

# %%
type(a), type(b)
# Out:
# (bool, bool)

# %% [markdown]
# ### 논리 및 비교연산

# %%
a == 0 # '=='같다 비교연산자
# Out:
# False

# %%
a
# Out:
# True

# %%
a == 1
# Out:
# True

# %%
a == "true"
# Out:
# False

# %%
b = 1
a and b ,a,b
# Out:
# (1, True, 1)

# %% [markdown]
# '''
# and: a,b 둘다 참
# or : 하나만 참
# not : 반대
# '''

# %%
a= True 
b=1 
a+b
# Out:
# 2

# %%
a and b
# Out:
# 1

# %%
a or b
# Out:
# True

# %%
a= None 
a and b

# %%
bool(0),bool(1),bool(2)
# Out:
# (False, True, True)

# %%
float(50.0)
# Out:
# 50.0

# %%
a=2
b=3

# %%
a+b,a-b,a*b,a/b,a//b,a% # 사칙연산
# Out:
# (5, -1, 6, 0.6666666666666666, 0, 2)

# %%
a==b,a>b,a !=b,a>=b#비교연산자
# Out:
# (False, False, True, False)

# %%
# 대입연산 +=,-=
a=10
a+=2
a
# Out:
# 12

# %%
a=10 
a -=2 
a
# Out:
# 8

# %% [markdown]
# ## 문자열 str

# %%
first_name = 'Geunchul'
last_name='hwang'
first_name+last_name
# Out:
# 'Geunchulhwang'

# %%
last_name == 'Hwnag'.title() # 소문자
# Out:
# False

# %%
last_name.title()
# Out:
# 'Hwang'

# %%
아기상어 = """
아기 상어 뚜 루루 뚜루
귀여운 뚜 루루 뚜루
바닷속 뚜 루루 뚜루
아기 상어!

엄마 상어 뚜 루루 뚜루
어여쁜 뚜 루루 뚜루
바닷속 뚜 루루 뚜루
엄마 상어!

아빠 상어 뚜 루루 뚜루
힘이 센 뚜 루루 뚜루
바닷속 뚜 루루 뚜루
아빠 상어!

할머니 상어 뚜 루루 뚜루
자상한 뚜 루루 뚜루
바닷속 뚜 루루 뚜루
할머니 상어!

할아버지 상어 뚜 루루 뚜루
멋있는 뚜 루루 뚜루
바닷속 뚜 루루 뚜루
할아버지 상어!

우리는 뚜 루루 뚜루
바다의 뚜 루루 뚜루
사냥꾼 뚜 루루 뚜루
상어 가족!

상어다 뚜 루루 뚜루
도망쳐 뚜 루루 뚜루
도망쳐 뚜 루루 뚜루
숨자! 으악!

살았다 뚜 루루 뚜루
살았다 뚜 루루 뚜루
오늘도 뚜 루루 뚜루
살았다
휴!

신난다 뚜 루루 뚜루
신난다 뚜 루루 뚜루
춤을 춰 뚜 루루 뚜루
노래 끝
오예!"""

아기상어.count("뚜루")
# Out:
# 27

# %%
주민등록번호="960329-1xxxxxxxx"
print(주민등록번호[0:6])
# Out:
# 960329

# %%
주민등록번호[2:4]
# Out:
# '03'

# %%
if __=='00':
    print ('젊은피')
else: 
    print ('틀띡')
# Out:
# 틀띡

# %%
year = 주민등록번호[0:2]
month= 주민등록번호[2:4]
day  = 주민등록번호[4:6]
if year =='00': 
    print (month)
else : 
    print(day) 
print(year)
print(month)
print(day)
# Out:
# 29
# 96
# 03
# 29

# %%
주민등록번호
# Out:
# '960329-1xxxxxxxx'

# %%
주민등록번호[-2:]
# Out:
# 'xx'

# %%
주민등록번호.replace(주민등록번호[7],"3")
# Out:
# '960329-3xxxxxxxx'

# %%
print(100 * "*")
# Out:
# ****************************************************************************************************

# %% [markdown]
# ### 인덱싱과 슬라이싱

# %%
text = "Python"
print(text[0:3])   # "Pyt"
print(text[2:])    # "thon"
print(text[:4])    # "Pyth"
print(text[-3:])   # "hon"
print(text[::2])   #??
# Out:
# Pyt
# thon
# Pyth
# hon
# Pto

# %%
'a'.encode('utf-8')
dec_value='a'.encode('utf-16')
dec_value
# Out:
# b'\xff\xfea\x00'

# %%
dec_value.decode('utf-16')
# Out:
# 'a'

# %%
#format()
#test_str='99.99 달러의 가치는 100달러의 가치가 있어용'
test_str='{0:.4f} {1:s}의 가치는 {2:d} 달러 의 가치가 있어용'
test_str.format(99.99,"$",100)
# Out:
# '99.9900 $의 가치는 100 달러 의 가치가 있어용'

# %%
num1=99
num2=100
str1='dollars'
test_str=f'{num1} {str1} are worth us $ {num2}이므니다'
test_str
# Out:
# '99 dollars are worth us $ 100이므니다'

# %%
len(test_str)
# Out:
# 33

# %%
email='aaa@gmail.com'
email_1='aaa@gmail.com '
email_2=' aaa@gmail.com '
len(email),len(email_1),len(email_2)
# Out:
# (13, 14, 15)

# %%
len(email.strip()),len(email_1.strip()),len(email_2.strip())
# Out:
# (13, 13, 13)

# %%
아기상어.rfind('뚜루루')
# Out:
# -1

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# # 문자열
# 1. 인덱싱,슬라이싱,멤버십
# 2. 문자열 불변, 대소문자 구분
# 3. 문자열은 코드를 지정 : 인코딩,디코딩 유니코드,한글 다됨
# 4. 문자열 덧셈 ,곱셉 존재
# 5. 공백처리,형식처리 등을 해야한다

# %%
import re

text = "파이썬   문자열   처리"
clean = re.sub(r"\s+", " ", text)

print(clean)
# Out:
# 파이썬 문자열 처리

# %%
tel_no='010-1557-8884'
re.sub(r'\D',"",tel_no)
# Out:
# '01015578884'

# %%
# 생성자 creator, function
int(1)
float(1)
str()
list[]
tuple()#()
dict()#{}
set()# {}

# %%
# 사칙연산자, 비교연산자, 논리연산자,대입연산자
+,=,/,%,//
>,<,==,!=
=,+=,-=,*=,/=
and ,or, not,&,|,!
in

# %%
#타입별 메소드 제공 
dir('a')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list_obj.append()
list_obj.insert() #리스트 요소
