# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Mary's cosmetic")
# Out:
# Mary's cosmetic

# %%
print("신 씨가 소리질렀다"+'"도둑이야"')
# Out:
# 신 씨가 소리질렀다"도둑이야"

# %%
print("C:\Windows")
# Out:
# C:\Windows
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18048\3538380946.py:1: SyntaxWarning: invalid escape sequence '\W'
#   print("C:\Windows")

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.") # \n 은 문장 줄 바꾸기, \t 는 탭
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print ("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
print("naver;kakao;sk;samsung")
# Out:
# naver;kakao;sk;samsung

# %%
print("naver/kakao/sk/samsung")
# Out:
# naver/kakao/sk/samsung

# %%
print("first", end=("second"))
# Out:
# firstsecond

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %%
삼성전자=50000
보유수=10
평가금액= 삼성전자* 보유수
print(평가금액)
# Out:
# 500000

# %%
시가=2980000000000000
현재가=50000
PER=15.79
print(시가,type(시가))
print(현재가,type(현재가))
print(PER,type(PER))
# Out:
# 2980000000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
s = "hello"
t = "python"
print(s+"!",t)
# Out:
# hello! python

# %%
2+2*3
# Out:
# 8

# %%
a = "132"
type(a)
# Out:
# str

# %%
num_str = "720"
new_val=int(num_str)
print(new_val)
# Out:
# 720

# %%
num=100
new_str=str(num)
print(new_str,type(new_str))
# Out:
# 100 <class 'str'>

# %%
a= "15.79"
A=float(a)
print(A,type(A))
# Out:
# 15.79 <class 'float'>

# %%
year = "2020"
A=int(year)
print(A-1);print(A-2);print(A-3)
# Out:
# 2019
# 2018
# 2017

# %%
비용=48584
무이자=36
토탈=비용*무이자
print(토탈)
# Out:
# 1749024

# %%
letters ='python'
letters[0],letters[2]
# Out:
# ('p', 't')

# %%
license_plate = "24가 2210"
print(license_plate[3:])
# Out:
#  2210

# %%
string = "홀짝홀짝홀짝"
print(string[::2])
# Out:
# 홀홀홀

# %%
string = "PYTHON"
print(string[::-1])
# Out:
# NOHTYP

# %%
phone_number = "010-1111-2222"
new=phone_number.replace("-"," ")
new
# Out:
# '010 1111 2222'

# %%
new1=new.replace(" ","")
new1
# Out:
# '01011112222'

# %%
url = "http://sharebook.kr"
url_new=url.split(".")
url_new[-1]
# Out:
# 'kr'

# %%
lang = 'python'
lang[0]
# Out:
# 'p'

# %%
string = 'abcdfe2a354a32a'
string.replace("a","A")
# Out:
# 'Abcdfe2A354A32A'

# %%
string = 'abcd'
string.replace('b', 'B') #aBcd
print(string)#abcd
# Out:
# abcd

# %%
a = "3"
b= "4"
print(a+b)
# Out:
# 34

# %%
print("Hi" * 3)#hi 3개 연달아
# Out:
# HiHiHi

# %%
print("-"*80)
# Out:
# --------------------------------------------------------------------------------

# %%
t1 = 'python' 
t2 = 'java'
t3=(t1+' '+t2+" ")
print(t3*4)
# Out:
# python java python java python java python java

# %%
name1 = "김민수" 
age1 = 10
name2 = "이철희"
age2 = 13
print("이름: %s 나이: %d" % (name1, age1))
print("이름: %s 나이: %d" % (name2, age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
name1 = "김민수" 
age1 = 10
name2 = "이철희"
age2 = 13
print("이름: {} 나이: {}" .format(name1, age1))
print("이름: {} 나이: {}" .format(name2, age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
name1 = "김민수" 
age1 = 10
name2 = "이철희"
age2 = 13
print(f"이름: {name1} 나이: {age1}")
print(f"이름: {name2} 나이: {age2}")
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
상장주식수 = "5,969,782,550"
a=상장주식수.replace(",",'')
print(int(a))
# Out:
# 5969782550

# %%
분기 = "2020/03(E) (IFRS연결)"
print(분기[0:7])
# Out:
# 2020/03

# %%
data = "   삼성전자    "
data.strip()
# Out:
# '삼성전자'

# %%
ticker = "btc_krw"
ticker.upper()
# Out:
# 'BTC_KRW'

# %%
ticker = "BTC_KRW"
ticker.lower()
# Out:
# 'btc_krw'

# %%
print('hello'.capitalize())
# Out:
# Hello

# %%
file_name = "보고서.xlsx"
file_name.endswith("xlsx")
# Out:
# True

# %%
file_name = "보고서.xlsx"
file_name.endswith('xlsx' or 'xls')
# Out:
# True

# %%
file_name = "2020_보고서.xlsx"
file_name.startswith('2020')
# Out:
# True

# %%
a = "hello world"
a.split()
# Out:
# ['hello', 'world']

# %%
ticker = "btc_krw"
ticker.split('_')
# Out:
# ['btc', 'krw']

# %%
date = "2020-05-01"
date.split("-")
# Out:
# ['2020', '05', '01']

# %%
data = "039490     "
data.rstrip()
# Out:
# '039490'

# %%
movie_rank=["닥터 스트레인지","스플릿","럭키"] 
movie_rank.append("배트맨")
movie_rank
# Out:
# ['닥터 스트레인지', '스플릿', '럭키', '배트맨']

# %%
movie_rank = ['닥터 스트레인지', '스플릿', '럭키', '배트맨']
movie_rank.insert(1,'슈퍼맨')
movie_rank
# Out:
# ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']

# %%
과일 = ["사과", "귤", "수박"]
for 변수 in 과일:
    print(변수)
# Out:
# 사과
# 귤
# 수박

# %%
변수 = [10,20,30]
for a in 변수: 
    print(a)
# Out:
# 10
# 20
# 30

# %%
ohlc = [["open", "high", "low", "close"],
        [100, 110, 70, 100],
        [200, 210, 180, 190],
        [300, 310, 300, 310]]
for row in ohlc:
    if row[3]>=row[0]:
        print (row[3])
# Out:
# 100
# 310
